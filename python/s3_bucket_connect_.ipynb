# %% [markdown]
# # AWS S3 CONNECT VIA PYSPARK-HIVE

# %%
from pyspark.sql import SparkSession, HiveContext
import pyspark.sql.functions as F
from pyspark.sql.types import *

# %%
spark = SparkSession \
    .builder \
    .appName("s3 bucket connect") \
    .config("spark.driver.memory", "2g") \
    .config("spark.executor.memory", "10g") \
    .config("spark.executor.instances","10")\
    .config("spark.jars","/home/mouli/hadoop-2.9.1/share/hadoop/tools/lib/aws-java-sdk-bundle-1.11.199.jar,/home/mouli/hadoop-2.9.1/share/hadoop/tools/lib/hadoop-aws-2.9.1.jar") \
    .config("hive.metastore.uris", "thrift://localhost:9083")\
    .enableHiveSupport()\
    .getOrCreate()

# %%
buketName="awsbucket25/employee.json"

# %% [markdown]
# AWS SECURITY CREDENTIALS TO ACCESS THE S3 BUCKET IN PROGRAMMATIC WAY

# %%
AWS_ACCESS_KEY_ID='AWS_ACCESS_KEY_ID'
AWS_SECRET_ACCESS_KEY='AWS_SECRET_ACCESS_KEY'

# %%
sc= spark.sparkContext

# %% [markdown]
# PARAMETERS TO SET HADOOP CONFIGURATION VALUES FROM PYSPARK

# %%
sc._jsc.hadoopConfiguration().set("fs.s3n.awsAccessKeyId", AWS_ACCESS_KEY_ID)
sc._jsc.hadoopConfiguration().set("fs.s3n.awsSecretAccessKey", AWS_SECRET_ACCESS_KEY)

# %% [markdown]
# READING THE EMPLOYEE JSON DATASET FROM S3

# %%
inputFile= sc.textFile("s3n://{}".format(buketName))

# %%
data = spark.read.json(inputFile)

# %%
data.printSchema()
# Out:
# root
#  |-- Employees: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- emailAddress: string (nullable = true)
#  |    |    |-- employeeCode: string (nullable = true)
#  |    |    |-- firstName: string (nullable = true)
#  |    |    |-- jobTitleName: string (nullable = true)
#  |    |    |-- lastName: string (nullable = true)
#  |    |    |-- phoneNumber: string (nullable = true)
#  |    |    |-- preferredFullName: string (nullable = true)
#  |    |    |-- region: string (nullable = true)
#  |    |    |-- userId: string (nullable = true)

# %%
data.show()
# Out:
# +--------------------+
# |           Employees|
# +--------------------+
# |[[romin.k.irani@g...|
# +--------------------+

# %%
data.columns
# Out:
# ['Employees']

# %%
field_info=[]
field_info.append(1)
def function_to_flatten_json(input_df):
    flat_columns = [c[0] for c in input_df.dtypes if c[1][:6] != 'struct' and c[1][:5] !="array"]
    print("flat_columns : ",flat_columns )
    nested_columns = [c[0] for c in input_df.dtypes if c[1][:6] == 'struct']
    array_columns=[c[0] for c in input_df.dtypes if c[1][:5] == 'array']
    print("array_columns",array_columns)
    print("nested_columns :",nested_columns)
    for ac in array_columns:
        input_df=input_df.select(flat_columns+nested_columns+[x for x in array_columns if x <> ac ]+[F.explode(ac).alias(ac)])
        print(input_df.columns)
    input_df = input_df.select(flat_columns +array_columns+
                               [F.col(nested_column+'.'+c).alias(nested_column+'_'+c)
                                for nested_column in nested_columns
                                for c in input_df.select(nested_column+'.*').columns])
    field_info.pop()
    field_info.append(input_df)
    print("input_dataframe ",",".join([x[1][:6] for x in input_df.dtypes]))
    new_nested=[c[0] for c in input_df.dtypes if c[1][:6] == 'struct']
    new_array=[c[0] for c in input_df.dtypes if c[1][:5] == 'array']
    if new_nested or new_array :        
        function_to_flatten_json(input_df)
function_to_flatten_json(data)
field_info_df=field_info[0]
# Out:
# ('flat_columns : ', [])
# ('array_columns', ['Employees'])
# ('nested_columns :', [])
# ['Employees']
# ('input_df ', 'struct')
# ('flat_columns : ', [])
# ('array_columns', [])
# ('nested_columns :', ['Employees'])
# ('input_df ', 'string,string,string,string,string,string,string,string,string')

# %%
field_info_df_pandas=field_info_df.toPandas()

# %%
field_info_df_pandas.head(5).T
# Out:
#                                                    0                     1  \
# Employees_emailAddress       romin.k.irani@gmail.com  neilrirani@gmail.com
# Employees_employeeCode                            E1                    E2
# Employees_firstName                            Romin                  Neil
# Employees_jobTitleName                     Developer             Developer
# Employees_lastName                             Irani                 Irani
# Employees_phoneNumber                    408-1234567           408-1111111
# Employees_preferredFullName              Romin Irani            Neil Irani
# Employees_region                                  CA                    CA
# Employees_userId                              rirani                nirani
#
#                                               2
# Employees_emailAddress       tomhanks@gmail.com
# Employees_employeeCode                       E3
# Employees_firstName                         Tom
# Employees_jobTitleName        Program Directory
# Employees_lastName                        Hanks
# Employees_phoneNumber               408-2222222
# Employees_preferredFullName           Tom Hanks
# Employees_region                             CA
# Employees_userId                         thanks

# %% [markdown]
# SAVING THE JSON DATA PROCESSED FROM S3 TO HIVE TABLES

# %%
field_info_df.write.mode("overwrite").format("orc").saveAsTable("dev_usr.employee_information")

# %%
show_db = spark.sql('show databases')
show_db.show()
# Out:
# +------------+
# |databaseName|
# +------------+
# |     default|
# |     dev_usr|
# +------------+

# %%
use_db=spark.sql('use dev_usr')
show_tables=spark.sql('show tables')
show_tables.show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | dev_usr|employee_information|      false|
# +--------+--------------------+-----------+

# %%
show_info=spark.sql("select * from dev_usr.employee_information")

# %%
show_info.show()
# Out:
# +----------------------+----------------------+-------------------+----------------------+------------------+---------------------+---------------------------+----------------+----------------+
# |Employees_emailAddress|Employees_employeeCode|Employees_firstName|Employees_jobTitleName|Employees_lastName|Employees_phoneNumber|Employees_preferredFullName|Employees_region|Employees_userId|
# +----------------------+----------------------+-------------------+----------------------+------------------+---------------------+---------------------------+----------------+----------------+
# |  romin.k.irani@gma...|                    E1|              Romin|             Developer|             Irani|          408-1234567|                Romin Irani|              CA|          rirani|
# |  neilrirani@gmail.com|                    E2|               Neil|             Developer|             Irani|          408-1111111|                 Neil Irani|              CA|          nirani|
# |    tomhanks@gmail.com|                    E3|                Tom|     Program Directory|             Hanks|          408-2222222|                  Tom Hanks|              CA|          thanks|
# +----------------------+----------------------+-------------------+----------------------+------------------+---------------------+---------------------------+----------------+----------------+

# %% [markdown]
# READING THE PHARMACY JSON DATASET FROM S3

# %%
bucket_name="awsbucket25/pharmacy-medication.json"
input_schema= sc.textFile("s3n://{}".format(bucket_name))

# %%
pharm_data = spark.read.json(input_schema)

# %%
pharm_data.printSchema()
# Out:
# root
#  |-- careTeam: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- provider: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |-- created: string (nullable = true)
#  |-- diagnosis: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- diagnosisCodeableConcept: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |-- id: string (nullable = true)
#  |-- identifier: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- system: string (nullable = true)
#  |    |    |-- value: string (nullable = true)
#  |-- insurance: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |-- reference: string (nullable = true)
#  |    |    |-- focal: boolean (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |-- insurer: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- item: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- careTeamSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- detail: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- net: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- net: struct (nullable = true)
#  |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |-- value: long (nullable = true)
#  |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |-- quantity: struct (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |-- value: long (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- servicedDate: string (nullable = true)
#  |-- originalPrescription: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- patient: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- payee: struct (nullable = true)
#  |    |-- type: struct (nullable = true)
#  |    |    |-- coding: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |-- prescription: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- priority: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- code: string (nullable = true)
#  |-- provider: struct (nullable = true)
#  |    |-- reference: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- supportingInfo: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- category: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |-- code: struct (nullable = true)
#  |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |-- sequence: long (nullable = true)
#  |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |-- value: long (nullable = true)
#  |-- text: struct (nullable = true)
#  |    |-- div: string (nullable = true)
#  |    |-- status: string (nullable = true)
#  |-- total: struct (nullable = true)
#  |    |-- currency: string (nullable = true)
#  |    |-- value: long (nullable = true)
#  |-- type: struct (nullable = true)
#  |    |-- coding: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- system: string (nullable = true)
#  |-- use: string (nullable = true)

# %%
field_info=[]
field_info.append(1)
def function_to_flatten_json(input_df):
    flat_columns = [c[0] for c in input_df.dtypes if c[1][:6] != 'struct' and c[1][:5] !="array"]
    print("flat_columns : ",flat_columns )
    nested_columns = [c[0] for c in input_df.dtypes if c[1][:6] == 'struct']
    array_columns=[c[0] for c in input_df.dtypes if c[1][:5] == 'array']
    print("array_columns",array_columns)
    print("nested_columns :",nested_columns)
    for ac in array_columns:
        input_df=input_df.select(flat_columns+nested_columns+[x for x in array_columns if x <> ac ]+[F.explode(ac).alias(ac)])
        print(input_df.columns)
    input_df = input_df.select(flat_columns +array_columns+
                               [F.col(nested_column+'.'+c).alias(nested_column+'_'+c)
                                for nested_column in nested_columns
                                for c in input_df.select(nested_column+'.*').columns])
    field_info.pop()
    field_info.append(input_df)
    print("input_dataframe ",",".join([x[1][:6] for x in input_df.dtypes]))
    new_nested=[c[0] for c in input_df.dtypes if c[1][:6] == 'struct']
    new_array=[c[0] for c in input_df.dtypes if c[1][:5] == 'array']
    if new_nested or new_array :        
        function_to_flatten_json(input_df)
function_to_flatten_json(pharm_data)
field_info_df=field_info[0]
# Out:
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use'])
# ('array_columns', ['careTeam', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo'])
# ('nested_columns :', ['insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type'])
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo', 'careTeam']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'careTeam', 'identifier', 'insurance', 'item', 'supportingInfo', 'diagnosis']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'careTeam', 'diagnosis', 'insurance', 'item', 'supportingInfo', 'identifier']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'careTeam', 'diagnosis', 'identifier', 'item', 'supportingInfo', 'insurance']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'careTeam', 'diagnosis', 'identifier', 'insurance', 'supportingInfo', 'item']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer', 'originalPrescription', 'patient', 'payee', 'prescription', 'priority', 'provider', 'text', 'total', 'type', 'careTeam', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo']
# ('input_df ', 'string,string,string,string,string,struct,struct,struct,struct,struct,struct,string,string,string,struct,string,array<,string,string,string,string,bigint,array<')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value'])
# ('array_columns', ['priority_coding', 'type_coding'])
# ('nested_columns :', ['careTeam', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo', 'payee_type'])
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo', 'payee_type', 'type_coding', 'priority_coding']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam', 'diagnosis', 'identifier', 'insurance', 'item', 'supportingInfo', 'payee_type', 'priority_coding', 'type_coding']
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,struct,struct,struct,bigint,struct,bigint,string,string,struct,boolea,bigint,array<,array<,array<,struct,struct,struct,bigint,string,struct,struct,bigint,struct,array<')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence'])
# ('array_columns', ['item_careTeamSequence', 'item_detail', 'item_informationSequence', 'payee_type_coding'])
# ('nested_columns :', ['priority_coding', 'type_coding', 'careTeam_provider', 'diagnosis_diagnosisCodeableConcept', 'insurance_coverage', 'item_net', 'item_productOrService', 'item_quantity', 'supportingInfo_category', 'supportingInfo_code', 'supportingInfo_valueQuantity'])
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'priority_coding', 'type_coding', 'careTeam_provider', 'diagnosis_diagnosisCodeableConcept', 'insurance_coverage', 'item_net', 'item_productOrService', 'item_quantity', 'supportingInfo_category', 'supportingInfo_code', 'supportingInfo_valueQuantity', 'item_detail', 'item_informationSequence', 'payee_type_coding', 'item_careTeamSequence']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'priority_coding', 'type_coding', 'careTeam_provider', 'diagnosis_diagnosisCodeableConcept', 'insurance_coverage', 'item_net', 'item_productOrService', 'item_quantity', 'supportingInfo_category', 'supportingInfo_code', 'supportingInfo_valueQuantity', 'item_careTeamSequence', 'item_informationSequence', 'payee_type_coding', 'item_detail']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'priority_coding', 'type_coding', 'careTeam_provider', 'diagnosis_diagnosisCodeableConcept', 'insurance_coverage', 'item_net', 'item_productOrService', 'item_quantity', 'supportingInfo_category', 'supportingInfo_code', 'supportingInfo_valueQuantity', 'item_careTeamSequence', 'item_detail', 'payee_type_coding', 'item_informationSequence']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'priority_coding', 'type_coding', 'careTeam_provider', 'diagnosis_diagnosisCodeableConcept', 'insurance_coverage', 'item_net', 'item_productOrService', 'item_quantity', 'supportingInfo_category', 'supportingInfo_code', 'supportingInfo_valueQuantity', 'item_careTeamSequence', 'item_detail', 'item_informationSequence', 'payee_type_coding']
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,bigint,bigint,string,string,boolea,bigint,bigint,string,bigint,bigint,struct,bigint,struct,string,string,string,string,array<,string,string,bigint,array<,string,string,string,bigint,array<,array<,bigint')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value'])
# ('array_columns', ['diagnosis_diagnosisCodeableConcept_coding', 'item_productOrService_coding', 'supportingInfo_category_coding', 'supportingInfo_code_coding'])
# ('nested_columns :', ['item_detail', 'payee_type_coding'])
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail', 'payee_type_coding', 'item_productOrService_coding', 'supportingInfo_category_coding', 'supportingInfo_code_coding', 'diagnosis_diagnosisCodeableConcept_coding']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail', 'payee_type_coding', 'diagnosis_diagnosisCodeableConcept_coding', 'supportingInfo_category_coding', 'supportingInfo_code_coding', 'item_productOrService_coding']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail', 'payee_type_coding', 'diagnosis_diagnosisCodeableConcept_coding', 'item_productOrService_coding', 'supportingInfo_code_coding', 'supportingInfo_category_coding']
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail', 'payee_type_coding', 'diagnosis_diagnosisCodeableConcept_coding', 'item_productOrService_coding', 'supportingInfo_category_coding', 'supportingInfo_code_coding']
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,bigint,bigint,string,string,boolea,bigint,bigint,string,bigint,bigint,bigint,string,string,string,string,string,string,bigint,string,string,string,bigint,bigint,struct,struct,struct,struct,struct,struct,bigint,string')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail_sequence', 'payee_type_coding_code'])
# ('array_columns', [])
# ('nested_columns :', ['diagnosis_diagnosisCodeableConcept_coding', 'item_productOrService_coding', 'supportingInfo_category_coding', 'supportingInfo_code_coding', 'item_detail_net', 'item_detail_productOrService'])
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,bigint,bigint,string,string,boolea,bigint,bigint,string,bigint,bigint,bigint,string,string,string,string,string,string,bigint,string,string,string,bigint,bigint,bigint,string,string,string,string,string,string,string,string,string,bigint,array<')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail_sequence', 'payee_type_coding_code', 'diagnosis_diagnosisCodeableConcept_coding_code', 'item_productOrService_coding_code', 'item_productOrService_coding_display', 'item_productOrService_coding_system', 'supportingInfo_category_coding_code', 'supportingInfo_code_coding_code', 'supportingInfo_code_coding_system', 'item_detail_net_currency', 'item_detail_net_value'])
# ('array_columns', ['item_detail_productOrService_coding'])
# ('nested_columns :', [])
# ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail_sequence', 'payee_type_coding_code', 'diagnosis_diagnosisCodeableConcept_coding_code', 'item_productOrService_coding_code', 'item_productOrService_coding_display', 'item_productOrService_coding_system', 'supportingInfo_category_coding_code', 'supportingInfo_code_coding_code', 'supportingInfo_code_coding_system', 'item_detail_net_currency', 'item_detail_net_value', 'item_detail_productOrService_coding']
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,bigint,bigint,string,string,boolea,bigint,bigint,string,bigint,bigint,bigint,string,string,string,string,string,string,bigint,string,string,string,bigint,bigint,bigint,string,string,string,string,string,string,string,string,string,bigint,struct')
# ('flat_columns : ', ['created', 'id', 'resourceType', 'status', 'use', 'insurer_reference', 'originalPrescription_reference', 'patient_reference', 'prescription_reference', 'provider_reference', 'text_div', 'text_status', 'total_currency', 'total_value', 'careTeam_sequence', 'diagnosis_sequence', 'identifier_system', 'identifier_value', 'insurance_focal', 'insurance_sequence', 'item_sequence', 'item_servicedDate', 'supportingInfo_sequence', 'item_careTeamSequence', 'item_informationSequence', 'priority_coding_code', 'type_coding_code', 'type_coding_system', 'careTeam_provider_reference', 'insurance_coverage_reference', 'item_net_currency', 'item_net_value', 'item_quantity_code', 'item_quantity_system', 'item_quantity_unit', 'item_quantity_value', 'supportingInfo_valueQuantity_value', 'item_detail_sequence', 'payee_type_coding_code', 'diagnosis_diagnosisCodeableConcept_coding_code', 'item_productOrService_coding_code', 'item_productOrService_coding_display', 'item_productOrService_coding_system', 'supportingInfo_category_coding_code', 'supportingInfo_code_coding_code', 'supportingInfo_code_coding_system', 'item_detail_net_currency', 'item_detail_net_value'])
# ('array_columns', [])
# ('nested_columns :', ['item_detail_productOrService_coding'])
# ('input_df ', 'string,string,string,string,string,string,string,string,string,string,string,string,string,bigint,bigint,bigint,string,string,boolea,bigint,bigint,string,bigint,bigint,bigint,string,string,string,string,string,string,bigint,string,string,string,bigint,bigint,bigint,string,string,string,string,string,string,string,string,string,bigint,string,string')

# %%
field_info_df_pandas=field_info_df.toPandas()
field_info_df_pandas.head(5).T
# Out:
#                                                                                                 0  \
# created                                                                                2014-08-16
# id                                                                                         760151
# resourceType                                                                                Claim
# status                                                                                     active
# use                                                                                         claim
# insurer_reference                                                                  Organization/2
# originalPrescription_reference                      http://pharmacy.org/MedicationRequest/AB1202B
# patient_reference                                                                       Patient/1
# prescription_reference                              http://pharmacy.org/MedicationRequest/AB1234G
# provider_reference                                                                 Organization/1
# text_div                                        <div xmlns="http://www.w3.org/1999/xhtml">A hu...
# text_status                                                                             generated
# total_currency                                                                                USD
# total_value                                                                                    90
# careTeam_sequence                                                                               1
# diagnosis_sequence                                                                              1
# identifier_system                                                    http://happypharma.com/claim
# identifier_value                                                                          7612345
# insurance_focal                                                                              True
# insurance_sequence                                                                              1
# item_sequence                                                                                   1
# item_servicedDate                                                                      2014-08-16
# supportingInfo_sequence                                                                         1
# item_careTeamSequence                                                                           1
# item_informationSequence                                                                        1
# priority_coding_code                                                                         stat
# type_coding_code                                                                         pharmacy
# type_coding_system                               http://terminology.hl7.org/CodeSystem/claim-type
# careTeam_provider_reference                                                  Practitioner/example
# insurance_coverage_reference                                                      Coverage/9876B1
# item_net_currency                                                                             USD
# item_net_value                                                                                 90
# item_quantity_code                                                                            TAB
# item_quantity_system                                                    http://unitsofmeasure.org
# item_quantity_unit                                                                            TAB
# item_quantity_value                                                                            90
# supportingInfo_valueQuantity_value                                                            NaN
# item_detail_sequence                                                                            1
# payee_type_coding_code                                                                   provider
# diagnosis_diagnosisCodeableConcept_coding_code                                             654456
# item_productOrService_coding_code                                                          562721
# item_productOrService_coding_display                                    Alprazolam 0.25mg (Xanax)
# item_productOrService_coding_system                   http://www.nlm.nih.gov/research/umls/rxnorm
# supportingInfo_category_coding_code                                                pharmacyrefill
# supportingInfo_code_coding_code                                                               new
# supportingInfo_code_coding_system               http://example.org/fhir/CodeSystem/pharmacy-re...
# item_detail_net_currency                                                                      USD
# item_detail_net_value                                                                          45
# item_detail_productOrService_coding_code                                                 drugcost
# item_detail_productOrService_coding_system                   http://hl7.org/fhir/ex-pharmaservice
#
#                                                                                                 1  \
# created                                                                                2014-08-16
# id                                                                                         760151
# resourceType                                                                                Claim
# status                                                                                     active
# use                                                                                         claim
# insurer_reference                                                                  Organization/2
# originalPrescription_reference                      http://pharmacy.org/MedicationRequest/AB1202B
# patient_reference                                                                       Patient/1
# prescription_reference                              http://pharmacy.org/MedicationRequest/AB1234G
# provider_reference                                                                 Organization/1
# text_div                                        <div xmlns="http://www.w3.org/1999/xhtml">A hu...
# text_status                                                                             generated
# total_currency                                                                                USD
# total_value                                                                                    90
# careTeam_sequence                                                                               1
# diagnosis_sequence                                                                              1
# identifier_system                                                    http://happypharma.com/claim
# identifier_value                                                                          7612345
# insurance_focal                                                                              True
# insurance_sequence                                                                              1
# item_sequence                                                                                   1
# item_servicedDate                                                                      2014-08-16
# supportingInfo_sequence                                                                         1
# item_careTeamSequence                                                                           1
# item_informationSequence                                                                        2
# priority_coding_code                                                                         stat
# type_coding_code                                                                         pharmacy
# type_coding_system                               http://terminology.hl7.org/CodeSystem/claim-type
# careTeam_provider_reference                                                  Practitioner/example
# insurance_coverage_reference                                                      Coverage/9876B1
# item_net_currency                                                                             USD
# item_net_value                                                                                 90
# item_quantity_code                                                                            TAB
# item_quantity_system                                                    http://unitsofmeasure.org
# item_quantity_unit                                                                            TAB
# item_quantity_value                                                                            90
# supportingInfo_valueQuantity_value                                                            NaN
# item_detail_sequence                                                                            1
# payee_type_coding_code                                                                   provider
# diagnosis_diagnosisCodeableConcept_coding_code                                             654456
# item_productOrService_coding_code                                                          562721
# item_productOrService_coding_display                                    Alprazolam 0.25mg (Xanax)
# item_productOrService_coding_system                   http://www.nlm.nih.gov/research/umls/rxnorm
# supportingInfo_category_coding_code                                                pharmacyrefill
# supportingInfo_code_coding_code                                                               new
# supportingInfo_code_coding_system               http://example.org/fhir/CodeSystem/pharmacy-re...
# item_detail_net_currency                                                                      USD
# item_detail_net_value                                                                          45
# item_detail_productOrService_coding_code                                                 drugcost
# item_detail_productOrService_coding_system                   http://hl7.org/fhir/ex-pharmaservice
#
#                                                                                                 2  \
# created                                                                                2014-08-16
# id                                                                                         760151
# resourceType                                                                                Claim
# status                                                                                     active
# use                                                                                         claim
# insurer_reference                                                                  Organization/2
# originalPrescription_reference                      http://pharmacy.org/MedicationRequest/AB1202B
# patient_reference                                                                       Patient/1
# prescription_reference                              http://pharmacy.org/MedicationRequest/AB1234G
# provider_reference                                                                 Organization/1
# text_div                                        <div xmlns="http://www.w3.org/1999/xhtml">A hu...
# text_status                                                                             generated
# total_currency                                                                                USD
# total_value                                                                                    90
# careTeam_sequence                                                                               1
# diagnosis_sequence                                                                              1
# identifier_system                                                    http://happypharma.com/claim
# identifier_value                                                                          7612345
# insurance_focal                                                                              True
# insurance_sequence                                                                              1
# item_sequence                                                                                   1
# item_servicedDate                                                                      2014-08-16
# supportingInfo_sequence                                                                         1
# item_careTeamSequence                                                                           1
# item_informationSequence                                                                        3
# priority_coding_code                                                                         stat
# type_coding_code                                                                         pharmacy
# type_coding_system                               http://terminology.hl7.org/CodeSystem/claim-type
# careTeam_provider_reference                                                  Practitioner/example
# insurance_coverage_reference                                                      Coverage/9876B1
# item_net_currency                                                                             USD
# item_net_value                                                                                 90
# item_quantity_code                                                                            TAB
# item_quantity_system                                                    http://unitsofmeasure.org
# item_quantity_unit                                                                            TAB
# item_quantity_value                                                                            90
# supportingInfo_valueQuantity_value                                                            NaN
# item_detail_sequence                                                                            1
# payee_type_coding_code                                                                   provider
# diagnosis_diagnosisCodeableConcept_coding_code                                             654456
# item_productOrService_coding_code                                                          562721
# item_productOrService_coding_display                                    Alprazolam 0.25mg (Xanax)
# item_productOrService_coding_system                   http://www.nlm.nih.gov/research/umls/rxnorm
# supportingInfo_category_coding_code                                                pharmacyrefill
# supportingInfo_code_coding_code                                                               new
# supportingInfo_code_coding_system               http://example.org/fhir/CodeSystem/pharmacy-re...
# item_detail_net_currency                                                                      USD
# item_detail_net_value                                                                          45
# item_detail_productOrService_coding_code                                                 drugcost
# item_detail_productOrService_coding_system                   http://hl7.org/fhir/ex-pharmaservice
#
#                                                                                                 3  \
# created                                                                                2014-08-16
# id                                                                                         760151
# resourceType                                                                                Claim
# status                                                                                     active
# use                                                                                         claim
# insurer_reference                                                                  Organization/2
# originalPrescription_reference                      http://pharmacy.org/MedicationRequest/AB1202B
# patient_reference                                                                       Patient/1
# prescription_reference                              http://pharmacy.org/MedicationRequest/AB1234G
# provider_reference                                                                 Organization/1
# text_div                                        <div xmlns="http://www.w3.org/1999/xhtml">A hu...
# text_status                                                                             generated
# total_currency                                                                                USD
# total_value                                                                                    90
# careTeam_sequence                                                                               1
# diagnosis_sequence                                                                              1
# identifier_system                                                    http://happypharma.com/claim
# identifier_value                                                                          7612345
# insurance_focal                                                                              True
# insurance_sequence                                                                              1
# item_sequence                                                                                   1
# item_servicedDate                                                                      2014-08-16
# supportingInfo_sequence                                                                         1
# item_careTeamSequence                                                                           1
# item_informationSequence                                                                        1
# priority_coding_code                                                                         stat
# type_coding_code                                                                         pharmacy
# type_coding_system                               http://terminology.hl7.org/CodeSystem/claim-type
# careTeam_provider_reference                                                  Practitioner/example
# insurance_coverage_reference                                                      Coverage/9876B1
# item_net_currency                                                                             USD
# item_net_value                                                                                 90
# item_quantity_code                                                                            TAB
# item_quantity_system                                                    http://unitsofmeasure.org
# item_quantity_unit                                                                            TAB
# item_quantity_value                                                                            90
# supportingInfo_valueQuantity_value                                                            NaN
# item_detail_sequence                                                                            2
# payee_type_coding_code                                                                   provider
# diagnosis_diagnosisCodeableConcept_coding_code                                             654456
# item_productOrService_coding_code                                                          562721
# item_productOrService_coding_display                                    Alprazolam 0.25mg (Xanax)
# item_productOrService_coding_system                   http://www.nlm.nih.gov/research/umls/rxnorm
# supportingInfo_category_coding_code                                                pharmacyrefill
# supportingInfo_code_coding_code                                                               new
# supportingInfo_code_coding_system               http://example.org/fhir/CodeSystem/pharmacy-re...
# item_detail_net_currency                                                                      USD
# item_detail_net_value                                                                           9
# item_detail_productOrService_coding_code                                                   markup
# item_detail_productOrService_coding_system                   http://hl7.org/fhir/ex-pharmaservice
#
#                                                                                                 4
# created                                                                                2014-08-16
# id                                                                                         760151
# resourceType                                                                                Claim
# status                                                                                     active
# use                                                                                         claim
# insurer_reference                                                                  Organization/2
# originalPrescription_reference                      http://pharmacy.org/MedicationRequest/AB1202B
# patient_reference                                                                       Patient/1
# prescription_reference                              http://pharmacy.org/MedicationRequest/AB1234G
# provider_reference                                                                 Organization/1
# text_div                                        <div xmlns="http://www.w3.org/1999/xhtml">A hu...
# text_status                                                                             generated
# total_currency                                                                                USD
# total_value                                                                                    90
# careTeam_sequence                                                                               1
# diagnosis_sequence                                                                              1
# identifier_system                                                    http://happypharma.com/claim
# identifier_value                                                                          7612345
# insurance_focal                                                                              True
# insurance_sequence                                                                              1
# item_sequence                                                                                   1
# item_servicedDate                                                                      2014-08-16
# supportingInfo_sequence                                                                         1
# item_careTeamSequence                                                                           1
# item_informationSequence                                                                        2
# priority_coding_code                                                                         stat
# type_coding_code                                                                         pharmacy
# type_coding_system                               http://terminology.hl7.org/CodeSystem/claim-type
# careTeam_provider_reference                                                  Practitioner/example
# insurance_coverage_reference                                                      Coverage/9876B1
# item_net_currency                                                                             USD
# item_net_value                                                                                 90
# item_quantity_code                                                                            TAB
# item_quantity_system                                                    http://unitsofmeasure.org
# item_quantity_unit                                                                            TAB
# item_quantity_value                                                                            90
# supportingInfo_valueQuantity_value                                                            NaN
# item_detail_sequence                                                                            2
# payee_type_coding_code                                                                   provider
# diagnosis_diagnosisCodeableConcept_coding_code                                             654456
# item_productOrService_coding_code                                                          562721
# item_productOrService_coding_display                                    Alprazolam 0.25mg (Xanax)
# item_productOrService_coding_system                   http://www.nlm.nih.gov/research/umls/rxnorm
# supportingInfo_category_coding_code                                                pharmacyrefill
# supportingInfo_code_coding_code                                                               new
# supportingInfo_code_coding_system               http://example.org/fhir/CodeSystem/pharmacy-re...
# item_detail_net_currency                                                                      USD
# item_detail_net_value                                                                           9
# item_detail_productOrService_coding_code                                                   markup
# item_detail_productOrService_coding_system                   http://hl7.org/fhir/ex-pharmaservice

# %% [markdown]
# SAVING THE JSON DATA PROCESSED FROM S3 TO HIVE TABLES

# %%
field_info_df.write.mode("overwrite").format("orc").saveAsTable("dev_usr.pharmacy_information")

# %%
show_info=spark.sql("select * from dev_usr.pharmacy_information")
show_info.show()
# Out:
# +----------+------+------------+------+-----+-----------------+------------------------------+-----------------+----------------------+------------------+--------------------+-----------+--------------+-----------+-----------------+------------------+--------------------+----------------+---------------+------------------+-------------+-----------------+-----------------------+---------------------+------------------------+--------------------+----------------+--------------------+---------------------------+----------------------------+-----------------+--------------+------------------+--------------------+------------------+-------------------+----------------------------------+--------------------+----------------------+----------------------------------------------+---------------------------------+------------------------------------+-----------------------------------+-----------------------------------+-------------------------------+---------------------------------+------------------------+---------------------+----------------------------------------+------------------------------------------+
# |   created|    id|resourceType|status|  use|insurer_reference|originalPrescription_reference|patient_reference|prescription_reference|provider_reference|            text_div|text_status|total_currency|total_value|careTeam_sequence|diagnosis_sequence|   identifier_system|identifier_value|insurance_focal|insurance_sequence|item_sequence|item_servicedDate|supportingInfo_sequence|item_careTeamSequence|item_informationSequence|priority_coding_code|type_coding_code|  type_coding_system|careTeam_provider_reference|insurance_coverage_reference|item_net_currency|item_net_value|item_quantity_code|item_quantity_system|item_quantity_unit|item_quantity_value|supportingInfo_valueQuantity_value|item_detail_sequence|payee_type_coding_code|diagnosis_diagnosisCodeableConcept_coding_code|item_productOrService_coding_code|item_productOrService_coding_display|item_productOrService_coding_system|supportingInfo_category_coding_code|supportingInfo_code_coding_code|supportingInfo_code_coding_system|item_detail_net_currency|item_detail_net_value|item_detail_productOrService_coding_code|item_detail_productOrService_coding_system|
# +----------+------+------------+------+-----+-----------------+------------------------------+-----------------+----------------------+------------------+--------------------+-----------+--------------+-----------+-----------------+------------------+--------------------+----------------+---------------+------------------+-------------+-----------------+-----------------------+---------------------+------------------------+--------------------+----------------+--------------------+---------------------------+----------------------------+-----------------+--------------+------------------+--------------------+------------------+-------------------+----------------------------------+--------------------+----------------------+----------------------------------------------+---------------------------------+------------------------------------+-----------------------------------+-----------------------------------+-------------------------------+---------------------------------+------------------------+---------------------+----------------------------------------+------------------------------------------+
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      1|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                              null|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                     pharmacyrefill|                            new|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   2|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                    9|                                  markup|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      2|                    1|                       3|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                 2|                   3|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|               refillsremaining|             http://example.or...|                     USD|                   36|                             dispensefee|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      3|                    1|                       1|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                90|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|                     dayssupply|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# |2014-08-16|760151|       Claim|active|claim|   Organization/2|          http://pharmacy.o...|        Patient/1|  http://pharmacy.o...|    Organization/1|<div xmlns="http:...|  generated|           USD|         90|                1|                 1|http://happypharm...|         7612345|           true|                 1|            1|       2014-08-16|                      3|                    1|                       2|                stat|        pharmacy|http://terminolog...|       Practitioner/example|             Coverage/9876B1|              USD|            90|               TAB|http://unitsofmea...|               TAB|                 90|                                90|                   1|              provider|                                        654456|                           562721|                Alprazolam 0.25mg...|               http://www.nlm.ni...|                pharmacyinformation|                     dayssupply|             http://example.or...|                     USD|                   45|                                drugcost|                      http://hl7.org/fh...|
# +----------+------+------------+------+-----+-----------------+------------------------------+-----------------+----------------------+------------------+--------------------+-----------+--------------+-----------+-----------------+------------------+--------------------+----------------+---------------+------------------+-------------+-----------------+-----------------------+---------------------+------------------------+--------------------+----------------+--------------------+---------------------------+----------------------------+-----------------+--------------+------------------+--------------------+------------------+-------------------+----------------------------------+--------------------+----------------------+----------------------------------------------+---------------------------------+------------------------------------+-----------------------------------+-----------------------------------+-------------------------------+---------------------------------+------------------------+---------------------+----------------------------------------+------------------------------------------+
# only showing top 20 rows
